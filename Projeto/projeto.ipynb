# %% [markdown]
# # Processamento de Aprendizagem

# %% [markdown]
# ## Problema 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problema 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problema 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Análise Exploratória

# %%
# importa bibliotecas
import pandas as pd

# %% [markdown]
# ## Engenharia dos Dados e Pré-processamentos

# %% [markdown]
# ## Modelos

# %% [markdown]
# ## Conclusão
